# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
airports_df = pd.read_csv('./Resource Files/airports.csv')
airports_df
# Out:
#     IATA                              AIRPORT          City STATE  \
# 0    ADK                                 Adak          Adak    AK
# 1    ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2    BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3    BET                               Bethel        Bethel    AK
# 4    CDV              Merle K (Mudhole) Smith       Cordova    AK
# ..   ...                                  ...           ...   ...
# 336  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 337  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 338  MQT             Marquette County Airport           NaN   NaN
# 339  SCE                      University Park           NaN   NaN
# 340  SPN         Tinian International Airport           NaN   NaN
#
#                COUNTRY   LATITUDE   LONGITUDE
# 0                  USA  51.877964 -176.646031
# 1                  USA  61.174320 -149.996186
# ...

# %%
airports_df_sorted = airports_df.sort_values(by=["STATE","City"])

# %%
airports_df_sorted.head(20)
airports_df_sorted.rename(columns={"CITY":"City"}, inplace=True)
airports_df_sorted
# Out:
#     IATA                              AIRPORT          City STATE  \
# 0    ADK                                 Adak          Adak    AK
# 1    ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2    BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3    BET                               Bethel        Bethel    AK
# 4    CDV              Merle K (Mudhole) Smith       Cordova    AK
# ..   ...                                  ...           ...   ...
# 336  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 337  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 338  MQT             Marquette County Airport           NaN   NaN
# 339  SCE                      University Park           NaN   NaN
# 340  SPN         Tinian International Airport           NaN   NaN
#
#                COUNTRY   LATITUDE   LONGITUDE
# 0                  USA  51.877964 -176.646031
# 1                  USA  61.174320 -149.996186
# ...

# %%
airports_df_sorted.to_csv('airports.csv', index=False)

# %%
zillow_df=pd.read_csv('./Resource Files/Zillow.csv')
zillow_df
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
zillow_df_sorted = zillow_df.sort_values(by=['State', 'City'])

# %%
zillow_df_sorted.to_csv('zillow.csv', index=False)

# %%
merged_df=pd.merge(airports_df_sorted, zillow_df_sorted, on="City", how="left")

# %%
merged_df
# Out:
#      IATA                              AIRPORT          City STATE  \
# 0     ADK                                 Adak          Adak    AK
# 1     ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2     BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3     BET                               Bethel        Bethel    AK
# 4     BET                               Bethel        Bethel    AK
# ...   ...                                  ...           ...   ...
# 1435  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 1436  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 1437  MQT             Marquette County Airport           NaN   NaN
# 1438  SCE                      University Park           NaN   NaN
# 1439  SPN         Tinian International Airport           NaN   NaN
#
#                 COUNTRY   LATITUDE   LONGITUDE  RegionID  SizeRank RegionType  \
# 0                   USA  51.877964 -176.646031       NaN       NaN        NaN
# ...

# %%
merged_df_clean = merged_df.dropna()

# %%
merged_df_clean
# Out:
#      IATA                              AIRPORT        City STATE COUNTRY  \
# 1     ANC  Ted Stevens Anchorage International   Anchorage    AK     USA
# 3     BET                               Bethel      Bethel    AK     USA
# 4     BET                               Bethel      Bethel    AK     USA
# 6     BET                               Bethel      Bethel    AK     USA
# 10    BET                               Bethel      Bethel    AK     USA
# ...   ...                                  ...         ...   ...     ...
# 1405  HTS               Tri-State Walker-Long   Huntington    WV     USA
# 1409  LWB                    Greenbrier Valley   Lewisburg    WV     USA
# 1428  JAC                         Jackson Hole     Jackson    WY     USA
# 1430  JAC                         Jackson Hole     Jackson    WY     USA
# 1431  JAC                         Jackson Hole     Jackson    WY     USA
#
#        LATITUDE   LONGITUDE  RegionID  SizeRank RegionType  ... 6/30/2020  \
# ...

# %%
merged_df_clean.to_csv('merged.csv', index=False)

# %%
merged_df_clean.columns
# Out:
# Index(['IATA', 'AIRPORT', 'City', 'STATE', 'COUNTRY', 'LATITUDE', 'LONGITUDE',
#        'RegionID', 'SizeRank', 'RegionType',
#        ...
#        '6/30/2020', '7/31/2020', '8/31/2020', '9/30/2020', '10/31/2020',
#        '11/30/2020', '12/31/2020', '1/31/2021', '2/28/2021', '3/31/2021'],
#       dtype='object', length=317)

# %%
merged_df_clean.dtypes
# Out:
# IATA           object
# AIRPORT        object
# City           object
# STATE          object
# COUNTRY        object
#                ...
# 11/30/2020    float64
# 12/31/2020    float64
# 1/31/2021     float64
# 2/28/2021     float64
# 3/31/2021     float64
# Length: 317, dtype: object

# %%
airport_traffic_df = pd.read_csv('./Resource Files/airport_ratings_passengers.csv')
airport_traffic_df
del airport_traffic_df['Unnamed: 0']
airport_traffic_df
# Out:
#                                                Airport Code  \
# 0           Los Angeles, CA: Los Angeles International  LAX
# 1            Chicago, IL: Chicago O'Hare International  ORD
# 2                     Denver, CO: Denver International  DEN
# 3    Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  ATL
# 4                      Boston, MA: Logan International  BOS
# ..                                                 ...  ...
# 381                  Telluride, CO: Telluride Regional  TEX
# 382                Dodge City, KS: Dodge City Regional  DDC
# 383           Provincetown, MA: Provincetown Municipal  PVC
# 384   Rutland, VT: Rutland - Southern Vermont Regional  RUT
# 385                 Rockland, ME: Knox County Regional  RKD
#
#     Originating Domestic Passengers 10%  Originating Domestic Passengers
# 0                             1,564,494                         15644940
# 1                             1,266,224                         12662240
# ...

# %%
zillow_sales = zillow_df
zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
col_list = list(zillow_sales)
col_list
years=['1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009' , '2010', 
       '2011', ' 2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021(Q1)']
print(years)
# Out:
# ['1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', ' 2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021(Q1)']

# %%
num = 8
num1 = 20
zillow_sales_save = zillow_sales

for year in years:
    zillow_sales[f'{year}_Total']=zillow_sales.iloc[:,num:num1].sum(axis=1)
    zillow_sales[f'{year}_Mean']=zillow_sales.iloc[:,num:num1].mean(axis=1)
    test=zillow_sales.iloc[0,num:num1]
    print(test)
    num=num1
    if year == '2020':
        num1 += 3
    else:
        num1+=12
# Out:
# 1/31/1996     NaN
# 2/29/1996     NaN
# 3/31/1996     NaN
# 4/30/1996     NaN
# 5/31/1996     NaN
# 6/30/1996     NaN
# 7/31/1996     NaN
# 8/31/1996     NaN
# 9/30/1996     NaN
# 10/31/1996    NaN
# 11/30/1996    NaN
# 12/31/1996    NaN
# Name: 0, dtype: object
# 1/31/1997     NaN
# 2/28/1997     NaN
# 3/31/1997     NaN
# 4/30/1997     NaN
# 5/31/1997     NaN
# 6/30/1997     NaN
# 7/31/1997     NaN
# 8/31/1997     NaN
# 9/30/1997     NaN
# 10/31/1997    NaN
# 11/30/1997    NaN
# 12/31/1997    NaN
# Name: 0, dtype: object
# 1/31/1998     NaN
# 2/28/1998     NaN
# 3/31/1998     NaN
# 4/30/1998     NaN
# 5/31/1998     NaN
# 6/30/1998     NaN
# 7/31/1998     NaN
# 8/31/1998     NaN
# 9/30/1998     NaN
# 10/31/1998    NaN
# 11/30/1998    NaN
# 12/31/1998    NaN
# Name: 0, dtype: object
# 1/31/1999     NaN
# 2/28/1999     NaN
# 3/31/1999     NaN
# 4/30/1999     NaN
# 5/31/1999     NaN
# 6/30/1999     NaN
# 7/31/1999     NaN
# 8/31/1999     NaN
# 9/30/1999     NaN
# 10/31/1999    NaN
# ...

# %%
col_list = list(zillow_sales)
col_list
zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
# zillow_sales['Test_Total']=(zillow_sales[['1/31/2000', '2/29/2000', '3/31/2000', '4/30/2000', '5/31/2000', '6/30/2000', '7/31/2000',
#                                           '8/31/2000','9/30/2000', '10/31/2000', '11/30/2000', '12/31/2000']].sum(axis=1))
zillow_sales['Test_Total']=(zillow_sales[['1/31/2021', '2/28/2021', '3/31/2021']].sum(axis=1))
zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
# zillow_sales['1996_Total']=zillow_sales.iloc[:,8:20].sum(axis=1)
# zillow_sales['1996_Mean']=zillow_sales.iloc[:,8:20].mean(axis=1)

# zillow_sales['1997_Total']=zillow_sales.iloc[:,20:32].sum(axis=1)
# zillow_sales['1997_Mean']=zillow_sales.iloc[:,20:32].mean(axis=1)

# zillow_sales['1998_Total']=zillow_sales.iloc[:,32:44].sum(axis=1)
# zillow_sales['1998_Mean']=zillow_sales.iloc[:,32:44].mean(axis=1)

# zillow_sales['1999_Total']=zillow_sales.iloc[:,44:56].sum(axis=1)
# zillow_sales['1999_Mean']=zillow_sales.iloc[:,44:56].mean(axis=1)

# %%
# zillow_sales['2000_Total']=zillow_sales.iloc[:,56:68].sum(axis=1)
# zillow_sales['2000_Mean']=zillow_sales.iloc[:,56:68].mean(axis=1)

# zillow_sales['2001_Total']=zillow_sales.iloc[:,68:80].sum(axis=1)
# zillow_sales['2001_Mean']=zillow_sales.iloc[:,68:80].mean(axis=1)

# zillow_sales['2002_Total']=zillow_sales.iloc[:,80:92].sum(axis=1)
# zillow_sales['2002_Mean']=zillow_sales.iloc[:,80:92].mean(axis=1)

# zillow_sales['2003_Total']=zillow_sales.iloc[:,92:104].sum(axis=1)
# zillow_sales['2003_Mean']=zillow_sales.iloc[:,92:104].mean(axis=1)

# zillow_sales['2004_Total']=zillow_sales.iloc[:,104:116].sum(axis=1)
# zillow_sales['2004_Mean']=zillow_sales.iloc[:,104:116].mean(axis=1)

# zillow_sales['2005_Total']=zillow_sales.iloc[:,116:128].sum(axis=1)
# zillow_sales['2005_Mean']=zillow_sales.iloc[:,116:128].mean(axis=1)

# zillow_sales['2006_Total']=zillow_sales.iloc[:,128:140].sum(axis=1)
# zillow_sales['2006_Mean']=zillow_sales.iloc[:,128:140].mean(axis=1)

# zillow_sales['2007_Total']=zillow_sales.iloc[:,140:152].sum(axis=1)
# zillow_sales['2007_Mean']=zillow_sales.iloc[:,140:152].mean(axis=1)

# zillow_sales['2008_Total']=zillow_sales.iloc[:,152:164].sum(axis=1)
# zillow_sales['2008_Mean']=zillow_sales.iloc[:,152:164].mean(axis=1)

# zillow_sales['2009_Total']=zillow_sales.iloc[:,164:176].sum(axis=1)
# zillow_sales['2009_Mean']=zillow_sales.iloc[:,164:176].mean(axis=1)

# zillow_sales['2010_Total']=zillow_sales.iloc[:,176:188].sum(axis=1)
# zillow_sales['2010_Mean']=zillow_sales.iloc[:,176:188].mean(axis=1)

# zillow_sales
# num=176
# num1=188
# test = zillow_sales.iloc[:,num:num1].sum(axis=1)
# test

# %%
# zillow_sales['2011_Total']=zillow_sales.iloc[:,188:200].sum(axis=1)
# zillow_sales['2011_Mean']=zillow_sales.iloc[:,188:200].mean(axis=1)

# zillow_sales['2012_Total']=zillow_sales.iloc[:,200:212].sum(axis=1)
# zillow_sales['2012_Mean']=zillow_sales.iloc[:,200:212].mean(axis=1)

# zillow_sales['2013_Total']=zillow_sales.iloc[:,212:224].sum(axis=1)
# zillow_sales['2013_Mean']=zillow_sales.iloc[:,212:224].mean(axis=1)

# zillow_sales['2014_Total']=zillow_sales.iloc[:,224:226].sum(axis=1)
# zillow_sales['2014_Mean']=zillow_sales.iloc[:,224:236].mean(axis=1)

# zillow_sales['2015_Total']=zillow_sales.iloc[:,236:248].sum(axis=1)
# zillow_sales['2015_Mean']=zillow_sales.iloc[:,236:248].mean(axis=1)

# zillow_sales['2016_Total']=zillow_sales.iloc[:,248:260].sum(axis=1)
# zillow_sales['2016_Mean']=zillow_sales.iloc[:,248:260].mean(axis=1)

# zillow_sales['2017_Total']=zillow_sales.iloc[:,260:272].sum(axis=1)
# zillow_sales['2017_Mean']=zillow_sales.iloc[:,260:272].mean(axis=1)

# zillow_sales['2018_Total']=zillow_sales.iloc[:,272:284].sum(axis=1)
# zillow_sales['2018_Mean']=zillow_sales.iloc[:,272:284].mean(axis=1)

# zillow_sales['2019_Total']=zillow_sales.iloc[:,284:296].sum(axis=1)
# zillow_sales['2019_Mean']=zillow_sales.iloc[:,284:296].mean(axis=1)

# zillow_sales

# %%
# zillow_sales['2020_Total']=zillow_sales.iloc[:,296:308].sum(axis=1)
# zillow_sales['2020_Mean']=zillow_sales.iloc[:,289:308].mean(axis=1)

# zillow_sales['2021_Total Q1']=zillow_sales.iloc[:,308:311].sum(axis=1)
# zillow_sales['2021_Mean Q1']=zillow_sales.iloc[:,308:311].mean(axis=1)

# %%
#state_group = zillow_sales.groupby(["State", "City"])
zillow_sales_states=zillow_sales.drop(columns=list(zillow_sales)[8:311])
states_col_list = list(zillow_sales_states)
states_col_list

#DELETE "Test_Total"
# Out:
# ['RegionID',
#  'SizeRank',
#  'City',
#  'RegionType',
#  'StateName',
#  'State',
#  'Metro',
#  'CountyName',
#  '1996_Total',
#  '1996_Mean',
#  '1997_Total',
#  '1997_Mean',
#  '1998_Total',
#  '1998_Mean',
#  '1999_Total',
#  '1999_Mean',
#  '2000_Total',
#  '2000_Mean',
#  '2001_Total',
#  '2001_Mean',
#  '2002_Total',
#  '2002_Mean',
#  '2003_Total',
#  '2003_Mean',
#  '2004_Total',
#  '2004_Mean',
#  '2005_Total',
#  '2005_Mean',
#  '2006_Total',
#  '2006_Mean',
#  '2007_Total',
#  '2007_Mean',
#  '2008_Total',
#  '2008_Mean',
#  '2009_Total',
#  '2009_Mean',
#  '2010_Total',
#  '2010_Mean',
#  '2011_Total',
#  '2011_Mean',
#  ' 2012_Total',
#  ' 2012_Mean',
#  '2013_Total',
#  '2013_Mean',
#  '2014_Total',
#  '2014_Mean',
#  '2015_Total',
#  '2015_Mean',
#  '2016_Total',
#  '2016_Mean',
#  '2017_Total',
#  '2017_Mean',
#  '2018_Total',
#  '2018_Mean',
#  '2019_Total',
#  '2019_Mean',
#  '2020_Total',
#  '2020_Mean',
#  '2021(Q1)_Total',
#  '2021(Q1)_Mean',
#  'Test_Total']

# %%
zillow_sales_states
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...
