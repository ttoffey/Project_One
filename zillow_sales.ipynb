# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
airports_df = pd.read_csv('./Resource Files/airports.csv')
airports_df
# Out:
#     IATA                              AIRPORT          City STATE  \
# 0    ADK                                 Adak          Adak    AK
# 1    ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2    BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3    BET                               Bethel        Bethel    AK
# 4    CDV              Merle K (Mudhole) Smith       Cordova    AK
# ..   ...                                  ...           ...   ...
# 336  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 337  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 338  MQT             Marquette County Airport           NaN   NaN
# 339  SCE                      University Park           NaN   NaN
# 340  SPN         Tinian International Airport           NaN   NaN
#
#                COUNTRY   LATITUDE   LONGITUDE
# 0                  USA  51.877964 -176.646031
# 1                  USA  61.174320 -149.996186
# ...

# %%
airports_df_sorted = airports_df.sort_values(by=["STATE","City"])

# %%
airports_df_sorted.head(20)
airports_df_sorted.rename(columns={"CITY":"City"}, inplace=True)
airports_df_sorted
# Out:
#     IATA                              AIRPORT          City STATE  \
# 0    ADK                                 Adak          Adak    AK
# 1    ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2    BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3    BET                               Bethel        Bethel    AK
# 4    CDV              Merle K (Mudhole) Smith       Cordova    AK
# ..   ...                                  ...           ...   ...
# 336  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 337  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 338  MQT             Marquette County Airport           NaN   NaN
# 339  SCE                      University Park           NaN   NaN
# 340  SPN         Tinian International Airport           NaN   NaN
#
#                COUNTRY   LATITUDE   LONGITUDE
# 0                  USA  51.877964 -176.646031
# 1                  USA  61.174320 -149.996186
# ...

# %%
airports_df_sorted.to_csv('airports.csv', index=False)

# %%
zillow_df=pd.read_csv('./Resource Files/Zillow.csv')
zillow_df
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
zillow_df_sorted = zillow_df.sort_values(by=['State', 'City'])

# %%
zillow_df_sorted.to_csv('zillow.csv', index=False)

# %%
merged_df=pd.merge(airports_df_sorted, zillow_df_sorted, on="City", how="left")

# %%
merged_df
# Out:
#      IATA                              AIRPORT          City STATE  \
# 0     ADK                                 Adak          Adak    AK
# 1     ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2     BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3     BET                               Bethel        Bethel    AK
# 4     BET                               Bethel        Bethel    AK
# ...   ...                                  ...           ...   ...
# 1435  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 1436  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 1437  MQT             Marquette County Airport           NaN   NaN
# 1438  SCE                      University Park           NaN   NaN
# 1439  SPN         Tinian International Airport           NaN   NaN
#
#                 COUNTRY   LATITUDE   LONGITUDE  RegionID  SizeRank RegionType  \
# 0                   USA  51.877964 -176.646031       NaN       NaN        NaN
# ...

# %%
merged_df_clean = merged_df.dropna()

# %%
merged_df_clean
# Out:
#      IATA                              AIRPORT        City STATE COUNTRY  \
# 1     ANC  Ted Stevens Anchorage International   Anchorage    AK     USA
# 3     BET                               Bethel      Bethel    AK     USA
# 4     BET                               Bethel      Bethel    AK     USA
# 6     BET                               Bethel      Bethel    AK     USA
# 10    BET                               Bethel      Bethel    AK     USA
# ...   ...                                  ...         ...   ...     ...
# 1405  HTS               Tri-State Walker-Long   Huntington    WV     USA
# 1409  LWB                    Greenbrier Valley   Lewisburg    WV     USA
# 1428  JAC                         Jackson Hole     Jackson    WY     USA
# 1430  JAC                         Jackson Hole     Jackson    WY     USA
# 1431  JAC                         Jackson Hole     Jackson    WY     USA
#
#        LATITUDE   LONGITUDE  RegionID  SizeRank RegionType  ... 6/30/2020  \
# ...

# %%
merged_df_clean.to_csv('merged.csv', index=False)

# %%
merged_df_clean.columns
# Out:
# Index(['IATA', 'AIRPORT', 'City', 'STATE', 'COUNTRY', 'LATITUDE', 'LONGITUDE',
#        'RegionID', 'SizeRank', 'RegionType',
#        ...
#        '6/30/2020', '7/31/2020', '8/31/2020', '9/30/2020', '10/31/2020',
#        '11/30/2020', '12/31/2020', '1/31/2021', '2/28/2021', '3/31/2021'],
#       dtype='object', length=317)

# %%
merged_df_clean.dtypes
# Out:
# IATA           object
# AIRPORT        object
# City           object
# STATE          object
# COUNTRY        object
#                ...
# 11/30/2020    float64
# 12/31/2020    float64
# 1/31/2021     float64
# 2/28/2021     float64
# 3/31/2021     float64
# Length: 317, dtype: object

# %%
airport_traffic_df = pd.read_csv('./Resource Files/airport_ratings_passengers.csv')
airport_traffic_df
del airport_traffic_df['Unnamed: 0']
airport_traffic_df
# Out:
#                                                Airport Code  \
# 0           Los Angeles, CA: Los Angeles International  LAX
# 1            Chicago, IL: Chicago O'Hare International  ORD
# 2                     Denver, CO: Denver International  DEN
# 3    Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  ATL
# 4                      Boston, MA: Logan International  BOS
# ..                                                 ...  ...
# 381                  Telluride, CO: Telluride Regional  TEX
# 382                Dodge City, KS: Dodge City Regional  DDC
# 383           Provincetown, MA: Provincetown Municipal  PVC
# 384   Rutland, VT: Rutland - Southern Vermont Regional  RUT
# 385                 Rockland, ME: Knox County Regional  RKD
#
#     Originating Domestic Passengers 10%  Originating Domestic Passengers
# 0                             1,564,494                         15644940
# 1                             1,266,224                         12662240
# ...

# %%
zillow_sales = zillow_df
zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
col_list = list(zillow_sales)
col_list
# Out:
# ['RegionID',
#  'SizeRank',
#  'City',
#  'RegionType',
#  'StateName',
#  'State',
#  'Metro',
#  'CountyName',
#  '1/31/1996',
#  '2/29/1996',
#  '3/31/1996',
#  '4/30/1996',
#  '5/31/1996',
#  '6/30/1996',
#  '7/31/1996',
#  '8/31/1996',
#  '9/30/1996',
#  '10/31/1996',
#  '11/30/1996',
#  '12/31/1996',
#  '1/31/1997',
#  '2/28/1997',
#  '3/31/1997',
#  '4/30/1997',
#  '5/31/1997',
#  '6/30/1997',
#  '7/31/1997',
#  '8/31/1997',
#  '9/30/1997',
#  '10/31/1997',
#  '11/30/1997',
#  '12/31/1997',
#  '1/31/1998',
#  '2/28/1998',
#  '3/31/1998',
#  '4/30/1998',
#  '5/31/1998',
#  '6/30/1998',
#  '7/31/1998',
#  '8/31/1998',
#  '9/30/1998',
#  '10/31/1998',
#  '11/30/1998',
#  '12/31/1998',
#  '1/31/1999',
#  '2/28/1999',
#  '3/31/1999',
#  '4/30/1999',
#  '5/31/1999',
#  '6/30/1999',
#  '7/31/1999',
#  '8/31/1999',
#  '9/30/1999',
#  '10/31/1999',
#  '11/30/1999',
#  '12/31/1999',
#  '1/31/2000',
#  '2/29/2000',
#  '3/31/2000',
#  '4/30/2000',
#  '5/31/2000',
#  '6/30/2000',
# ...

# %%
# zillow_sales['Test_Total']=(zillow_sales[['1/31/2000', '2/29/2000', '3/31/2000', '4/30/2000', '5/31/2000', '6/30/2000', '7/31/2000',
#                                           '8/31/2000','9/30/2000', '10/31/2000', '11/30/2000', '12/31/2000']].sum(axis=1))

# %%
zillow_sales['1996_Total']=zillow_sales.iloc[:,8:20].sum(axis=1)
zillow_sales['1996_Mean']=zillow_sales.iloc[:,8:20].mean(axis=1)

zillow_sales['1997_Total']=zillow_sales.iloc[:,20:32].sum(axis=1)
zillow_sales['1997_Mean']=zillow_sales.iloc[:,20:32].mean(axis=1)

zillow_sales['1998_Total']=zillow_sales.iloc[:,32:44].sum(axis=1)
zillow_sales['1998_Mean']=zillow_sales.iloc[:,32:44].mean(axis=1)

zillow_sales['1999_Total']=zillow_sales.iloc[:,44:56].sum(axis=1)
zillow_sales['1999_Mean']=zillow_sales.iloc[:,44:56].mean(axis=1)
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
zillow_sales['2000_Total']=zillow_sales.iloc[:,56:68].sum(axis=1)
zillow_sales['2000_Mean']=zillow_sales.iloc[:,56:68].mean(axis=1)

zillow_sales['2001_Total']=zillow_sales.iloc[:,68:70].sum(axis=1)
zillow_sales['2001_Mean']=zillow_sales.iloc[:,68:70].mean(axis=1)

zillow_sales['2002_Total']=zillow_sales.iloc[:,70:82].sum(axis=1)
zillow_sales['2002_Mean']=zillow_sales.iloc[:,70:82].mean(axis=1)

zillow_sales['2003_Total']=zillow_sales.iloc[:,82:94].sum(axis=1)
zillow_sales['2003_Mean']=zillow_sales.iloc[:,82:94].mean(axis=1)

zillow_sales['2004_Total']=zillow_sales.iloc[:,94:106].sum(axis=1)
zillow_sales['2004_Mean']=zillow_sales.iloc[:,94:106].mean(axis=1)

zillow_sales['2005_Total']=zillow_sales.iloc[:,106:118].sum(axis=1)
zillow_sales['2005_Mean']=zillow_sales.iloc[:,106:118].mean(axis=1)

zillow_sales['2006_Total']=zillow_sales.iloc[:,118:130].sum(axis=1)
zillow_sales['2006_Mean']=zillow_sales.iloc[:,118:130].mean(axis=1)

zillow_sales['2007_Total']=zillow_sales.iloc[:,130:142].sum(axis=1)
zillow_sales['2007_Mean']=zillow_sales.iloc[:,130:142].mean(axis=1)

zillow_sales['2008_Total']=zillow_sales.iloc[:,142:154].sum(axis=1)
zillow_sales['2008_Mean']=zillow_sales.iloc[:,142:154].mean(axis=1)

zillow_sales['2009_Total']=zillow_sales.iloc[:,154:166].sum(axis=1)
zillow_sales['2009_Mean']=zillow_sales.iloc[:,154:166].mean(axis=1)

zillow_sales['2010_Total']=zillow_sales.iloc[:,154:166].sum(axis=1)
zillow_sales['2010_Mean']=zillow_sales.iloc[:,154:166].mean(axis=1)

zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
zillow_sales['2011_Total']=zillow_sales.iloc[:,166:178].sum(axis=1)
zillow_sales['2011_Mean']=zillow_sales.iloc[:,166:178].mean(axis=1)

zillow_sales['2012_Total']=zillow_sales.iloc[:,178:190].sum(axis=1)
zillow_sales['2012_Mean']=zillow_sales.iloc[:,178:190].mean(axis=1)

zillow_sales['2013_Total']=zillow_sales.iloc[:,190:202].sum(axis=1)
zillow_sales['2013_Mean']=zillow_sales.iloc[:,190:202].mean(axis=1)

zillow_sales['2014_Total']=zillow_sales.iloc[:,202:214].sum(axis=1)
zillow_sales['2014_Mean']=zillow_sales.iloc[:,202:214].mean(axis=1)

zillow_sales['2015_Total']=zillow_sales.iloc[:,214:226].sum(axis=1)
zillow_sales['2015_Mean']=zillow_sales.iloc[:,214:226].mean(axis=1)

zillow_sales['2016_Total']=zillow_sales.iloc[:,226:238].sum(axis=1)
zillow_sales['2016_Mean']=zillow_sales.iloc[:,226:238].mean(axis=1)

zillow_sales['2017_Total']=zillow_sales.iloc[:,238:250].sum(axis=1)
zillow_sales['2017_Mean']=zillow_sales.iloc[:,238:250].mean(axis=1)

zillow_sales['2018_Total']=zillow_sales.iloc[:,250:262].sum(axis=1)
zillow_sales['2018_Mean']=zillow_sales.iloc[:,250:262].mean(axis=1)

zillow_sales['2019_Total']=zillow_sales.iloc[:,262:274].sum(axis=1)
zillow_sales['2019_Mean']=zillow_sales.iloc[:,262:274].mean(axis=1)

zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
zillow_sales['2020_Total']=zillow_sales.iloc[:,274:286].sum(axis=1)
zillow_sales['2020_Mean']=zillow_sales.iloc[:,274:286].mean(axis=1)

zillow_sales['2021_Total Q1']=zillow_sales.iloc[:,286:288].sum(axis=1)
zillow_sales['2021_Mean Q1']=zillow_sales.iloc[:,286:288].mean(axis=1)

# %%
zillow_sales
# Out:
#        RegionID  SizeRank          City RegionType StateName State      Metro  \
# 0         28124     21482  Anchor Point       City        AK    AK        NaN
# 1         23482        75     Anchorage       City        AK    AK  Anchorage
# 2         50997     16107      Big Lake       City        AK    AK  Anchorage
# 3          4089     20490       Chiniak       City        AK    AK        NaN
# 4         10832     29449    Clam Gulch       City        AK    AK        NaN
# ...         ...       ...           ...        ...       ...   ...        ...
# 25597     48466      6204     Wheatland       City        WY    WY        NaN
# 25598     14671     10281        Wilson       City        WY    WY    Jackson
# 25599     23322      6655       Worland       City        WY    WY        NaN
# 25600     34921     29449        Wright       City        WY    WY   Gillette
# 25601     36376     25059         Yoder       City        WY    WY        NaN
#
# ...

# %%
state_group = zillow_sales.groupby(["State", "City"])
state_group.sum()
# Out:
#                     RegionID  SizeRank  1/31/1996  2/29/1996  3/31/1996  \
# State City
# AK    Anchor Point     28124     21482        0.0        0.0        0.0
#       Anchorage        23482        75   124382.0   124813.0   125101.0
#       Big Lake         50997     16107        0.0        0.0        0.0
#       Chiniak           4089     20490        0.0        0.0        0.0
#       Clam Gulch       10832     29449        0.0        0.0        0.0
# ...                      ...       ...        ...        ...        ...
# WY    Wheatland        48466      6204        0.0        0.0        0.0
#       Wilson           14671     10281        0.0        0.0        0.0
#       Worland          23322      6655        0.0        0.0        0.0
#       Wright           34921     29449        0.0        0.0        0.0
#       Yoder            36376     25059        0.0        0.0        0.0
#
#                     4/30/1996  5/31/1996  6/30/1996  7/31/1996  8/31/1996  \
# State City
# ...
