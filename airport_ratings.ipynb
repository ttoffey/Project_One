# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
orig_df=pd.read_csv('./Resource Files/airport_ratings_passengers.csv')

# %%
orig_df
# Out:
#      Unnamed: 0                                            Airport Code  \
# 0             1         Los Angeles, CA: Los Angeles International  LAX
# 1             2          Chicago, IL: Chicago O'Hare International  ORD
# 2             3                   Denver, CO: Denver International  DEN
# 3             4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  ATL
# 4             5                    Boston, MA: Logan International  BOS
# ..          ...                                                ...  ...
# 381         382                  Telluride, CO: Telluride Regional  TEX
# 382         383                Dodge City, KS: Dodge City Regional  DDC
# 383         384           Provincetown, MA: Provincetown Municipal  PVC
# 384         385   Rutland, VT: Rutland - Southern Vermont Regional  RUT
# 385         386                 Rockland, ME: Knox County Regional  RKD
#
#     Originating Domestic Passengers 10%  Originating Domestic Passengers
# ...

# %%
df = orig_df.loc[orig_df['Originating Domestic Passengers']>=2000000]

# %%
df
# Out:
#     Unnamed: 0                                            Airport Code  \
# 0            1         Los Angeles, CA: Los Angeles International  LAX
# 1            2          Chicago, IL: Chicago O'Hare International  ORD
# 2            3                   Denver, CO: Denver International  DEN
# 3            4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  ATL
# 4            5                    Boston, MA: Logan International  BOS
# 5            6     San Francisco, CA: San Francisco International  SFO
# 6            7          Seattle, WA: Seattle/Tacoma International  SEA
# 7            8           Newark, NJ: Newark Liberty International  EWR
# 8            9  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...  DFW
# 9           10                 Orlando, FL: Orlando International  MCO
# 10          11        New York, NY: John F. Kennedy International  JFK
# 11          12      Phoenix, AZ: Phoenix Sky Harbor International  PHX
# ...

# %%
df_one=pd.read_csv('airports.csv')
df_one.rename(columns={"IATA": "Code"}, inplace=True)
df_one
# Out:
#     Code                              AIRPORT          CITY STATE  \
# 0    ADK                                 Adak          Adak    AK
# 1    ANC  Ted Stevens Anchorage International     Anchorage    AK
# 2    BRW      Wiley Post Will Rogers Memorial        Barrow    AK
# 3    BET                               Bethel        Bethel    AK
# 4    CDV              Merle K (Mudhole) Smith       Cordova    AK
# ..   ...                                  ...           ...   ...
# 336  RKS       Rock Springs-Sweetwater County  Rock Springs    WY
# 337  CLD           MC Clellan-Palomar Airport           NaN   NaN
# 338  MQT             Marquette County Airport           NaN   NaN
# 339  SCE                      University Park           NaN   NaN
# 340  SPN         Tinian International Airport           NaN   NaN
#
#                COUNTRY   LATITUDE   LONGITUDE
# 0                  USA  51.877964 -176.646031
# 1                  USA  61.174320 -149.996186
# ...

# %%
merged_airports = pd.merge(df, df_one, on="Code", how="left")
merged_airports
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-b409e0c22974> in <module>
# ----> 1 merged_airports = pd.merge(df, df_one, on="Code", how="left")
#       2 merged_airports
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...
